# %%
import h5py
import pandas as pd

# %%
file_path = '../InputOutput/C0213DLC_resnet50_Horse_SkeletonMay17shuffle1_1030000.h5'
new_file_path = 'C:/Users/14074/OneDrive/Desktop/dlc output/C0213DLC_resnet50_Horse_SkeletonMay17shuffle1_1030000.h5'
with h5py.File(new_file_path, 'r') as f:
        print(list(f.keys()))
# Out:
# ['df_with_missing']

# %%
df = pd.read_hdf(new_file_path)
print(df)
# Out:
# scorer    DLC_resnet50_Horse_SkeletonMay17shuffle1_1030000              \
# bodyparts                                       rightFhoof
# coords                                                   x           y
# 0                                               203.137329  511.365601
# 1                                               234.265732  528.517578
# 2                                               235.342407  528.869385
# 3                                               234.217941  528.202698
# 4                                               235.492783  528.205933
# ..                                                     ...         ...
# 376                                            1705.888550  524.246033
# 377                                            1713.049805  521.383240
# 378                                            1717.372314  518.807129
# 379                                            1681.627197  528.599976
# ...
